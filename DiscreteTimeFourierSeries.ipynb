# %% [markdown]
# <a href="https://colab.research.google.com/github/ThomasPazhaidam/Discrete-Signals-and-Systems/blob/main/DiscreteTimeFourierSeries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 3, Thomas Pazhaidam, 500952854, Section 10

# %% [markdown]
# # Part A: Discrete Time Fourier Series

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal

# %% [markdown]
# 1)
#
# Fundamental Period = 5
#
# Fundamental Frequency = (2/5)*pi

# %% [markdown]
# 2)

# %%
No=5
wo=0.4*np.pi
n=np.arange(0,5,1)
print(n)
x=4*np.cos(2.4*np.pi*n)+2*np.sin(3.2*np.pi*n)
x1=[]

for r in n:
    x1.append(sum((x*np.exp(-1j*r*wo*n)))/5)

plt.stem(n,x)
plt.xlabel('n')
plt.ylabel('x[n]')
# Out:
# [0 1 2 3 4]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   # This is added back by InteractiveShellApp.init_path()
# Text(0, 0.5, 'x[n]')

# %%
absx1=[abs(xs) for xs in x1]
plt.stem(n,absx1)
plt.xlabel('n')
plt.ylabel('|Dr|')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# Text(0, 0.5, '|Dr|')

# %%
anglex1=(np.angle(xs) for xs in x1)
plt.stem(n,np.angle(x1))
plt.xlabel('n')
plt.ylabel('Phase Dr')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# Text(0, 0.5, 'Phase Dr')

# %% [markdown]
# 3)

# %% [markdown]
# Fundamental Period = 6
#
# Fundamental Frequency = (1/3)*pi

# %%
n=np.arange(0,6,1)
y=[3,2,1,0,1,2]
wo=((1/3)*np.pi)
y1=[]
for r in range(6):
  y1.append(sum(y*np.exp(-1j*r*wo*n))/6)

absy1=[abs(ys) for ys in y1]

plt.stem(n,absy1)
plt.xlabel('n')
plt.ylabel('|Dr|')
# Out:
# [1.5, 0.6666666666666663, 5.033555242519377e-16, 0.16666666666666666, 1.0808451812457177e-15, 0.6666666666666672]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   if sys.path[0] == '':
# Text(0, 0.5, '|Dr|')

# %%
angley1=[np.angle(ys) for ys in y1]
plt.stem(n,angley1)
plt.xlabel('n')
plt.ylabel('Angle Dr')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# Text(0, 0.5, 'Angle Dr')

# %%
plt.stem(n,y)
plt.xlabel('n')
plt.ylabel('y[n]')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   """Entry point for launching an IPython kernel.
# Text(0, 0.5, 'y[n]')

# %% [markdown]
# # Part B: Inverse DTFS and the Time Shifting Property

# %% [markdown]
# 1)

# %%
No=32
n=np.arange(0,32,1)
wo=np.pi/16
xr=[]
for r in range(5):
  xr.append(1)
for r in range(23):
  xr.append(0)
for r in range(4):
  xr.append(1)

xn=[]
for r in range(32):
  xn.append(sum(xr*np.exp(1j*r*wo*n)))

plt.stem(n,xn)

plt.xlabel('n')
plt.ylabel('x[n]')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   app.launch_new_instance()
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1317: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1317: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# Text(0, 0.5, 'x[n]')

# %% [markdown]
# 2)

# %%
wo=(np.pi/16)
xr1=xr*np.exp(-1j*r*wo*n*10)

xn1=[]
for r in range(32):
  xn1.append(sum(xr1*np.exp(1j*r*wo*n)))

plt.stem(n,xn1)

plt.xlabel('n')
plt.ylabel('x[n]')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1317: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1317: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# Text(0, 0.5, 'x[n]')

# %% [markdown]
# x[n] in part B2 is x[n] in part B1 shifted to the left by 10

# %% [markdown]
# # Part C: System Response

# %% [markdown]
# 1)

# %%
def u(a, n):
    unit = np.array([])
    for sample in n:
        if sample<a:
            unit = np.append(unit,0)
        else:
            unit = np.append(unit,1)
    return(unit)
n=np.arange(-16,17,1)

H=u(-4,n)-u(5,n)
wo=(2*np.pi/32)

plt.stem(n*wo, H)
plt.xlabel('w')
plt.ylabel('H[w]')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# Text(0, 0.5, 'H[w]')

# %% [markdown]
# 2)

# %%
wo=(2*np.pi/32)

h1=[]
for r in range(5):
  h1.append(1)
for r in range(23):
  h1.append(0)
for r in range(4):
  h1.append(1)

n=np.arange(0,32,1)
x1=4*np.cos(np.pi*n/8)

X1=[]
for r in range(32):
  X1.append(sum(x1*np.exp(-1j*r*wo*n))/32)

absX1=[abs(Xs) for Xs in X1]

plt.stem(wo*n,np.multiply(h1,absX1))
plt.xlabel('w')
plt.ylabel('Y1[w]')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:20: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# Text(0, 0.5, 'Y1[w]')

# %% [markdown]
# 3)

# %%
wo=(2*np.pi/32)

h1=[]
for r in range(5):
  h1.append(1)
for r in range(23):
  h1.append(0)
for r in range(4):
  h1.append(1)

x2=4*np.cos(np.pi*n/2)
X2=[]
for r in range(32):
  X2.append(sum(x2*np.exp(-1j*r*wo*n))/32)

absX2=[abs(Xs) for Xs in X2]
plt.stem(wo*n,np.multiply(h1,absX2))
plt.yticks([0,2])
plt.xlabel('w')
plt.ylabel('Y2[w]')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# Text(0, 0.5, 'Y2[w]')

# %% [markdown]
# 4)
#
# for this LTID system a transfer function is convoluted with 2 different cosine signals. From observing the output of the system y1 after the convolution is applied, it can be found that several spectral components of the consine signal is missing after the system is applied. when looking at y2 it can be further observered that the entire spectrum has been zeroed by the system. This means this transfer function behaves like a filter which only allows outputs at certain frequesncies to pass.
